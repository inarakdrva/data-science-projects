# %%
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### Another way to create a plot

# %%
df1['A'].plot(kind='hist', bins=30, color='green')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area(alpha=0.5)

#alpha = transparency
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True, cmap='magma')
# Out:
# <Axes: >

# %%
df1.plot.line(y='B', figsize=(12,4), lw=1)

#figsize = size of the plot(resolution)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', c='C')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
#Demonstrating the difference by size:

df1.plot.scatter(x='A', y='B', s=df1['C']*90)
# Out:
# /Users/inarakadyrova/anaconda3/lib/python3.11/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a', 'b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.888479 -0.708559
# 1 -2.640145  0.667319
# 2 -0.696917  1.066068
# 3 -1.835584 -0.176250
# 4  0.253612 -0.047970

# %%
df.plot.hexbin(x='a', y='b', gridsize=30, cmap='viridis')

#gridsize = the size of the grid (smaller number=bigger size)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>
